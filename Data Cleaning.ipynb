# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('datanow1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
df.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
df.iloc[0:11,0:20]
# Out:
#     Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0       1  526301100           20        RL         141.0     31770   Pave
# 1       2  526350040           20        RH          80.0     11622   Pave
# 2       3  526351010           20        RL          81.0     14267   Pave
# 3       4  526353030           20        RL          93.0     11160   Pave
# 4       5  527105010           60        RL          74.0     13830   Pave
# 5       6  527105030           60        RL          78.0      9978   Pave
# 6       7  527127150          120        RL          41.0      4920   Pave
# 7       8  527145080          120        RL          43.0      5005   Pave
# 8       9  527146030          120        RL          39.0      5389   Pave
# 9      10  527162130           60        RL          60.0      7500   Pave
# 10     11  527163010           60        RL          75.0     10000   Pave
#
# ...

# %%
df.iloc[0:11,21:40]
# Out:
#     Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0             1960        Hip   CompShg      BrkFace      Plywood
# 1             1961      Gable   CompShg      VinylSd      VinylSd
# 2             1958        Hip   CompShg      Wd Sdng      Wd Sdng
# 3             1968        Hip   CompShg      BrkFace      BrkFace
# 4             1998      Gable   CompShg      VinylSd      VinylSd
# 5             1998      Gable   CompShg      VinylSd      VinylSd
# 6             2001      Gable   CompShg      CemntBd      CmentBd
# 7             1992      Gable   CompShg      HdBoard      HdBoard
# 8             1996      Gable   CompShg      CemntBd      CmentBd
# 9             1999      Gable   CompShg      VinylSd      VinylSd
# 10            1994      Gable   CompShg      HdBoard      HdBoard
#
#    Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0         Stone         112.0         TA         TA     CBlock        TA
# ...

# %%
df.iloc[0:11,41:60]
# Out:
#    Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# 0          Fa           Y      SBrkr        1656           0                0
# 1          TA           Y      SBrkr         896           0                0
# 2          TA           Y      SBrkr        1329           0                0
# 3          Ex           Y      SBrkr        2110           0                0
# 4          Gd           Y      SBrkr         928         701                0
# 5          Ex           Y      SBrkr         926         678                0
# 6          Ex           Y      SBrkr        1338           0                0
# 7          Ex           Y      SBrkr        1280           0                0
# 8          Ex           Y      SBrkr        1616           0                0
# 9          Gd           Y      SBrkr        1028         776                0
# 10         Gd           Y      SBrkr         763         892                0
#
# ...

# %%
df.iloc[0:11,61:82]
# Out:
#    Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 0            Fin          2.0        528.0          TA          TA
# 1            Unf          1.0        730.0          TA          TA
# 2            Unf          1.0        312.0          TA          TA
# 3            Fin          2.0        522.0          TA          TA
# 4            Fin          2.0        482.0          TA          TA
# 5            Fin          2.0        470.0          TA          TA
# 6            Fin          2.0        582.0          TA          TA
# 7            RFn          2.0        506.0          TA          TA
# 8            RFn          2.0        608.0          TA          TA
# 9            Fin          2.0        442.0          TA          TA
# 10           Fin          2.0        440.0          TA          TA
#
#    Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  ...  \
# 0            P           210             62               0           0  ...
# ...

# %% [markdown]
# ## Checking for null Values

# %%
df.iloc[0:,0:40].isnull().sum()
# Out:
# Order                0
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Lot Frontage       490
# Lot Area             0
# Street               0
# Alley             2732
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type        23
# Mas Vnr Area        23
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# ...

# %%
df.iloc[0:,41:82].isnull().sum()
# Out:
# Heating QC            0
# Central Air           0
# Electrical            1
# 1st Flr SF            0
# 2nd Flr SF            0
# Low Qual Fin SF       0
# Gr Liv Area           0
# Bsmt Full Bath        2
# Bsmt Half Bath        2
# Full Bath             0
# Half Bath             0
# Bedroom AbvGr         0
# Kitchen AbvGr         0
# Kitchen Qual          0
# TotRms AbvGrd         0
# Functional            0
# Fireplaces            0
# Fireplace Qu       1422
# Garage Type         157
# Garage Yr Blt       159
# Garage Finish       159
# Garage Cars           1
# Garage Area           1
# Garage Qual         159
# Garage Cond         159
# Paved Drive           0
# Wood Deck SF          0
# Open Porch SF         0
# Enclosed Porch        0
# 3Ssn Porch            0
# Screen Porch          0
# Pool Area             0
# Pool QC            2917
# Fence              2358
# Misc Feature       2824
# Misc Val              0
# Mo Sold               0
# Yr Sold               0
# ...

# %%
df.drop(['Misc Feature','Fence','Pool QC','Fireplace Qu','Alley'], axis = 1,inplace = True)

# %% [markdown]
# ## Filling Numerical null values

# %%
df[['Garage Area','Garage Cars','Garage Yr Blt','Bsmt Half Bath','Bsmt Full Bath','Total Bsmt SF','Bsmt Unf SF','BsmtFin SF 2','BsmtFin SF 1','Mas Vnr Area','Lot Frontage']]= df[['Garage Area','Garage Cars','Garage Yr Blt','Bsmt Half Bath','Bsmt Full Bath','Total Bsmt SF','Bsmt Unf SF','BsmtFin SF 2','BsmtFin SF 1','Mas Vnr Area','Lot Frontage']].interpolate(method = 'linear')

# %% [markdown]
# ## Filling Categorical null values

# %%
df['Mas Vnr Type'].value_counts()
# Out:
# None       1752
# BrkFace     880
# Stone       249
# BrkCmn       25
# CBlock        1
# Name: Mas Vnr Type, dtype: int64

# %%
df['Mas Vnr Type'].fillna('None', inplace = True)

# %%
df['BsmtFin Type 2'].value_counts()
# Out:
# Unf    2499
# Rec     106
# LwQ      89
# BLQ      68
# ALQ      53
# GLQ      34
# Name: BsmtFin Type 2, dtype: int64

# %%
df['BsmtFin Type 2'].fillna('Unf', inplace = True)

# %%
df['BsmtFin Type 1'].value_counts()
# Out:
# GLQ    859
# Unf    851
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: BsmtFin Type 1, dtype: int64

# %%
df['BsmtFin Type 1'].fillna('GLQ', inplace = True)

# %%
df['Garage Cond'].value_counts()
# Out:
# TA    2665
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: Garage Cond, dtype: int64

# %%
df['Garage Cond'].fillna('TA', inplace = True)

# %%
df['Garage Qual'].value_counts()
# Out:
# TA    2615
# Fa     124
# Gd      24
# Po       5
# Ex       3
# Name: Garage Qual, dtype: int64

# %%
df['Garage Qual'].fillna('TA', inplace = True)

# %%
df['Garage Finish'].value_counts()
# Out:
# Unf    1231
# RFn     812
# Fin     728
# Name: Garage Finish, dtype: int64

# %%
df['Garage Finish'].fillna('Unf', inplace = True)

# %%
df['Garage Type'].value_counts()
# Out:
# Attchd     1731
# Detchd      782
# BuiltIn     186
# Basment      36
# 2Types       23
# CarPort      15
# Name: Garage Type, dtype: int64

# %%
df['Garage Type'].fillna('Attchd', inplace = True)

# %%
df['Electrical'].value_counts()
# Out:
# SBrkr    2682
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: Electrical, dtype: int64

# %%
df['Electrical'].fillna('SBrkr', inplace = True)

# %%
df['Bsmt Qual'].value_counts()
# Out:
# TA    1283
# Gd    1219
# Ex     258
# Fa      88
# Po       2
# Name: Bsmt Qual, dtype: int64

# %%
df['Bsmt Qual'].fillna('TA', inplace = True)

# %%
df['Bsmt Cond'].value_counts()
# Out:
# TA    2616
# Gd     122
# Fa     104
# Po       5
# Ex       3
# Name: Bsmt Cond, dtype: int64

# %%
df['Bsmt Cond'].fillna('TA', inplace = True)

# %%
df['Bsmt Exposure'].value_counts()
# Out:
# No    1906
# Av     418
# Gd     284
# Mn     239
# Name: Bsmt Exposure, dtype: int64

# %%
df['Bsmt Exposure'].fillna('No', inplace = True)

# %%
df.iloc[0:,0:40].isnull().sum()
# Out:
# Order             0
# PID               0
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      0
# Lot Area          0
# Street            0
# Lot Shape         0
# Land Contour      0
# Utilities         0
# Lot Config        0
# Land Slope        0
# Neighborhood      0
# Condition 1       0
# Condition 2       0
# Bldg Type         0
# House Style       0
# Overall Qual      0
# Overall Cond      0
# Year Built        0
# Year Remod/Add    0
# Roof Style        0
# Roof Matl         0
# Exterior 1st      0
# Exterior 2nd      0
# Mas Vnr Type      0
# Mas Vnr Area      0
# Exter Qual        0
# Exter Cond        0
# Foundation        0
# Bsmt Qual         0
# Bsmt Cond         0
# Bsmt Exposure     0
# BsmtFin Type 1    0
# BsmtFin SF 1      0
# BsmtFin Type 2    0
# BsmtFin SF 2      0
# Bsmt Unf SF       0
# Total Bsmt SF     0
# Heating           0
# dtype: int64

# %%
df.iloc[0:,41:82].isnull().sum()
# Out:
# Central Air        0
# Electrical         0
# 1st Flr SF         0
# 2nd Flr SF         0
# Low Qual Fin SF    0
# Gr Liv Area        0
# Bsmt Full Bath     0
# Bsmt Half Bath     0
# Full Bath          0
# Half Bath          0
# Bedroom AbvGr      0
# Kitchen AbvGr      0
# Kitchen Qual       0
# TotRms AbvGrd      0
# Functional         0
# Fireplaces         0
# Garage Type        0
# Garage Yr Blt      0
# Garage Finish      0
# Garage Cars        0
# Garage Area        0
# Garage Qual        0
# Garage Cond        0
# Paved Drive        0
# Wood Deck SF       0
# Open Porch SF      0
# Enclosed Porch     0
# 3Ssn Porch         0
# Screen Porch       0
# Pool Area          0
# Misc Val           0
# Mo Sold            0
# Yr Sold            0
# Sale Type          0
# Sale Condition     0
# SalePrice          0
# dtype: int64

# %%
df.to_csv('datanow.csv')
